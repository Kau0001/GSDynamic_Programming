# %% [markdown]
# # Análise dos resultados
# Execute `src/performance_monitor.py` e carregue o JSON gerado em `data/processed/performance_results.json`.

# %%
import json, pandas as pd
from pathlib import Path
data=json.loads(Path("../data/processed/performance_results.json").read_text())
pd.DataFrame(data)
